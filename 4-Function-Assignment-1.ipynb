# %%
# Create a Class and Function,and list out the items in the list

# %%
Sub-fieldsInAI.Subfields()

# %%
print("Sub-fields in AI are:")
print("Machine Learning")
print("Neural Networks")
print("Vision")
print ("Robotics")
print("Speech Processing")
print("Natural Language processing")

# %%
# create a function that checks weather the given numbber is odd even

# %%
oddEven.oddeven()

# %%
num = int(input("Enter a number:"))
if num % 2 == 0:
    print(num,"Even number")
else:
    print(num, "is odd numbber")
# Out:
# Enter a number: 5242
# 5242 Even number

# %%
# Create a function that tells elegibility of marriage for male and female according 
to thei r age limit like 21 for male and 18 for female

# %%
ElegibilityForMarriage.Elegiable()

# %%
gender = input("Your Gender:")
age = int(input("Your Age:"))

if gender == "Male" and age >=21:
          print ("ELIGIBLE")
else:
          print("NOT ELIGIBLE")
# Out:
# Your Gender: Male
# Your Age: 20
# NOT ELIGIBLE

# %%
# Calculate the percentage of your 10th mark

# %%
FindPercent.Percentage()

# %%
Subject1 = 98
Subject2 = 87
Subject3 = 95
Subject4 = 95
Subject5 = 93

Total = Subject1 + Subject2 +  Subject3 +  Subject4 +  Subject5
Percentage = Total/5.0 + 0.0000000000001,
print("Subject1=",Subject1)
print("Subject2=",Subject2)
print("Subject3=",Subject3)
print("Subject4=",Subject4)
print("Subject5=",Subject5)
print("Total:",Total)
print ("Percentage :",Percentage)
# Out:
# Subject1= 98
# Subject2= 87
# Subject3= 95
# Subject4= 95
# Subject5= 93
# Total: 468
# Percentage : (93.6000000000001,)

# %%
#print area and perimeter of triangle of triangle using class and function

# %%
triangle.trianglge()

# %%
Height = 32
Breadth = 34

Area = (Height * Breadth)/2

print("Height:", Height)
print("Breadth:", Breadth)
print("Area formula: (Height*Breadth)/2")
print("Area of Triangle:",Area)

Height1 = 2
Height2 = 4
Breadth = 4
Perimeter = Height1 + Height2 + Breadth

print("Height1",Height1)
print("Height2",Height2)
print("Breadth",Breadth)
print("Perimeter formula: Height1+Height2+Breadth")
print("Perimeter of Triangle",Perimeter)
# Out:
# Height: 32
# Breadth: 34
# Area formula: (Height*Breadth)/2
# Area of Triangle: 544.0
# Height1 2
# Height2 4
# Breadth 4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle 10
